# %%
import pandas as pd

# %%
# Read csv
weekly_raffle_df = pd.read_csv("11.9.2020.csv")

# %%
# Drop all rows with missing values
weekly_raffle_df = weekly_raffle_df.dropna()

# %%
# Drop all rows with headers repeating
weekly_raffle_df = weekly_raffle_df[weekly_raffle_df.Username != "Username"]
weekly_raffle_df
# Out:
#          Date/Time                        Username Amount Deposited  \
# 0    11/9/20 17:05            rosadl4554@gmail.com          $20.00
# 1    11/9/20 14:36            r.elisenda@yahoo.com          $10.00
# 2    11/9/20 13:56      alexandreasymone@gmail.com          $20.00
# 3    11/9/20 12:03       angel6369garcia@gmail.com           $0.00
# 4     11/9/20 9:47           w.adolfo.rm@gmail.com          $10.00
# 5     11/9/20 1:22        egcastillo2017@gmail.com          $20.00
# 9   11/10/20 16:13        vickydeaguilar@gmail.com           $0.00
# 10  11/10/20 12:15              davidpina@live.com           $0.00
# 11  11/10/20 11:57              saytumax@yahoo.com           $0.00
# 12  11/10/20 11:01       aguilarelmer777@gmail.com           $0.00
# 13  11/10/20 10:27      carlos94mendoza@icloud.com          $20.00
# 14   11/10/20 9:11         jonesjared695@yahoo.com          $20.00
# 15   11/10/20 8:25           beajaimes83@gmail.com           $0.00
# ...

# %%
weekly_raffle_df.astype(str)
# Out:
#          Date/Time                        Username Amount Deposited  \
# 0    11/9/20 17:05            rosadl4554@gmail.com          $20.00
# 1    11/9/20 14:36            r.elisenda@yahoo.com          $10.00
# 2    11/9/20 13:56      alexandreasymone@gmail.com          $20.00
# 3    11/9/20 12:03       angel6369garcia@gmail.com           $0.00
# 4     11/9/20 9:47           w.adolfo.rm@gmail.com          $10.00
# 5     11/9/20 1:22        egcastillo2017@gmail.com          $20.00
# 9   11/10/20 16:13        vickydeaguilar@gmail.com           $0.00
# 10  11/10/20 12:15              davidpina@live.com           $0.00
# 11  11/10/20 11:57              saytumax@yahoo.com           $0.00
# 12  11/10/20 11:01       aguilarelmer777@gmail.com           $0.00
# 13  11/10/20 10:27      carlos94mendoza@icloud.com          $20.00
# 14   11/10/20 9:11         jonesjared695@yahoo.com          $20.00
# 15   11/10/20 8:25           beajaimes83@gmail.com           $0.00
# ...

# %%
# Convert Total Deposited values to float
weekly_raffle_df['Total Deposited'].str.replace('$', '').astype(float)
# Out:
# 0     20.0
# 1     10.0
# 2     20.0
# 3     10.0
# 4     10.0
# 5     20.0
# 9     20.0
# 10     5.0
# 11    20.0
# 12    10.0
# 13    20.0
# 14    20.0
# 15    10.0
# 16    10.0
# 20    20.0
# 21     6.0
# 22    20.0
# 23    10.0
# 24    20.0
# 25    10.0
# 26    20.0
# 27     2.0
# 28    20.0
# 29    20.0
# 33    20.0
# 34    10.0
# 35    15.0
# 39    10.0
# 40    20.0
# 41    10.0
# 42     5.0
# 43    10.0
# 47    10.0
# 48    40.0
# 49    50.0
# 50    15.0
# 51    20.0
# 52    10.0
# 53    20.0
# 54    20.0
# 55    20.0
# 56    20.0
# 57     5.0
# 63    10.0
# 64    20.0
# 65    10.0
# 66    10.0
# 67    10.0
# 68    15.0
# 69    20.0
# 70     5.0
# 71    20.0
# 72     3.0
# 73     9.0
# 74    10.0
# 75    10.0
# 76    13.0
# Name: Total Deposited, dtype: float64

# %%
weekly_raffle_df["Total Deposited"] = pd.to_numeric(weekly_raffle_df["Total Deposited"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$20.00 "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a1a9b625e65d> in <module>
# ----> 1 weekly_raffle_df["Total Deposited"] = pd.to_numeric(weekly_raffle_df["Total Deposited"])
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
weekly_raffle_df["Entries"] = weekly_raffle_df["Total Deposited"]/10
weekly_raffle_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ...
